# %% [markdown]
# ## IMPORT NECESSARY LIBRARIES

# %%
# %pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in c:\users\ayomi\anaconda3\lib\site-packages (14.0.2)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\ayomi\anaconda3\lib\site-packages (from pyarrow) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import datetime as dt
import polars as pl
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import time

# %% [markdown]
# ### READ CSV

# %%
flight_df = pl.read_csv(r'C:\Users\ayomi\OneDrive\Documents\GitHub\Activity1\flight\flights.csv')
airport_df = pl.read_csv(r'C:\Users\ayomi\OneDrive\Documents\GitHub\Activity1\flight\airports.csv')
airline_df = pl.read_csv(r'C:\Users\ayomi\OneDrive\Documents\GitHub\Activity1\flight\airlines.csv')

# %% [markdown]
# # FLIGHT DATA CLEANING

# %%
flight_df.head()
# Out:
# shape: (5, 31)
# ┌──────┬───────┬─────┬─────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ YEAR ┆ MONTH ┆ DAY ┆ DAY_OF_WEEK ┆ … ┆ SECURITY_DEL ┆ AIRLINE_DELA ┆ LATE_AIRCRAF ┆ WEATHER_DELA │
# │ ---  ┆ ---   ┆ --- ┆ ---         ┆   ┆ AY           ┆ Y            ┆ T_DELAY      ┆ Y            │
# │ i64  ┆ i64   ┆ i64 ┆ i64         ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │      ┆       ┆     ┆             ┆   ┆ i64          ┆ i64          ┆ i64          ┆ i64          │
# ╞══════╪═══════╪═════╪═════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ 2015 ┆ 1     ┆ 1   ┆ 4           ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# │ 2015 ┆ 1     ┆ 1   ┆ 4           ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# │ 2015 ┆ 1     ┆ 1   ┆ 4           ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# │ 2015 ┆ 1     ┆ 1   ┆ 4           ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# │ 2015 ┆ 1     ┆ 1   ┆ 4           ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# └──────┴───────┴─────┴─────────────┴───┴──────────────┴──────────────┴──────────────┴──────────────┘

# %%
flight_df.shape
# Out:
# (5819079, 31)

# %%
flight_df.null_count()
# Out:
# shape: (1, 31)
# ┌──────┬───────┬─────┬─────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ YEAR ┆ MONTH ┆ DAY ┆ DAY_OF_WEEK ┆ … ┆ SECURITY_DEL ┆ AIRLINE_DELA ┆ LATE_AIRCRAF ┆ WEATHER_DELA │
# │ ---  ┆ ---   ┆ --- ┆ ---         ┆   ┆ AY           ┆ Y            ┆ T_DELAY      ┆ Y            │
# │ u32  ┆ u32   ┆ u32 ┆ u32         ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │      ┆       ┆     ┆             ┆   ┆ u32          ┆ u32          ┆ u32          ┆ u32          │
# ╞══════╪═══════╪═════╪═════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ 0    ┆ 0     ┆ 0   ┆ 0           ┆ … ┆ 4755640      ┆ 4755640      ┆ 4755640      ┆ 4755640      │
# └──────┴───────┴─────┴─────────────┴───┴──────────────┴──────────────┴──────────────┴──────────────┘

# %% [markdown]
# ## check for duplicate row and drop them

# %%
flight_df.filter(flight_df.is_duplicated())
# Out:
# shape: (0, 31)
# ┌──────┬───────┬─────┬─────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ YEAR ┆ MONTH ┆ DAY ┆ DAY_OF_WEEK ┆ … ┆ SECURITY_DEL ┆ AIRLINE_DELA ┆ LATE_AIRCRAF ┆ WEATHER_DELA │
# │ ---  ┆ ---   ┆ --- ┆ ---         ┆   ┆ AY           ┆ Y            ┆ T_DELAY      ┆ Y            │
# │ i64  ┆ i64   ┆ i64 ┆ i64         ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │      ┆       ┆     ┆             ┆   ┆ i64          ┆ i64          ┆ i64          ┆ i64          │
# ╞══════╪═══════╪═════╪═════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# └──────┴───────┴─────┴─────────────┴───┴──────────────┴──────────────┴──────────────┴──────────────┘

# %%
flight_df.shape
# Out:
# (5819079, 31)

# %% [markdown]
# ## Detect outliers

# %%
columns =['FLIGHT_NUMBER',
 'SCHEDULED_ARRIVAL']
for col in columns:
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))


    sns.boxplot(x=flight_df[col])

    plt.title(f'Box Plot of {col}')
    plt.show()

# %%
flight_df.shape
# Out:
# (5819079, 31)

# %%
flight_df.head()
# Out:
# shape: (5, 31)
# ┌──────┬───────┬─────┬─────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ YEAR ┆ MONTH ┆ DAY ┆ DAY_OF_WEEK ┆ … ┆ SECURITY_DEL ┆ AIRLINE_DELA ┆ LATE_AIRCRAF ┆ WEATHER_DELA │
# │ ---  ┆ ---   ┆ --- ┆ ---         ┆   ┆ AY           ┆ Y            ┆ T_DELAY      ┆ Y            │
# │ i64  ┆ i64   ┆ i64 ┆ i64         ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │      ┆       ┆     ┆             ┆   ┆ i64          ┆ i64          ┆ i64          ┆ i64          │
# ╞══════╪═══════╪═════╪═════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ 2015 ┆ 1     ┆ 1   ┆ 4           ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# │ 2015 ┆ 1     ┆ 1   ┆ 4           ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# │ 2015 ┆ 1     ┆ 1   ┆ 4           ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# │ 2015 ┆ 1     ┆ 1   ┆ 4           ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# │ 2015 ┆ 1     ┆ 1   ┆ 4           ┆ … ┆ null         ┆ null         ┆ null         ┆ null         │
# └──────┴───────┴─────┴─────────────┴───┴──────────────┴──────────────┴──────────────┴──────────────┘

# %% [markdown]
# ## Rule based cleaning

# %% [markdown]
# ### Fix time- combine Year month and date into a datetime format

# %%
flight_df = flight_df.with_columns(
    pl.concat_str(
        [pl.col("YEAR"), pl.lit("-"), pl.col("MONTH").cast(pl.Utf8), pl.lit("-"), pl.col("DAY").cast(pl.Utf8)]
    ).alias("DATE").str.strptime(pl.Date)
)

flight_df = flight_df.drop(['YEAR', 'MONTH', 'DAY'])

# %%
flight_df.columns
# Out:
# ['DAY_OF_WEEK',
#  'AIRLINE',
#  'FLIGHT_NUMBER',
#  'TAIL_NUMBER',
#  'ORIGIN_AIRPORT',
#  'DESTINATION_AIRPORT',
#  'SCHEDULED_DEPARTURE',
#  'DEPARTURE_TIME',
#  'DEPARTURE_DELAY',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'SCHEDULED_TIME',
#  'ELAPSED_TIME',
#  'AIR_TIME',
#  'DISTANCE',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'SCHEDULED_ARRIVAL',
#  'ARRIVAL_TIME',
#  'ARRIVAL_DELAY',
#  'DIVERTED',
#  'CANCELLED',
#  'CANCELLATION_REASON',
#  'AIR_SYSTEM_DELAY',
#  'SECURITY_DELAY',
#  'AIRLINE_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'WEATHER_DELAY',
#  'DATE']

# %%
flight_df.head()
# Out:
# shape: (5, 29)
# ┌────────────┬─────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NU ┆ TAIL_NUMB ┆ … ┆ AIRLINE_D ┆ LATE_AIRC ┆ WEATHER_D ┆ DATE      │
# │ K          ┆ ---     ┆ MBER      ┆ ER        ┆   ┆ ELAY      ┆ RAFT_DELA ┆ ELAY      ┆ ---       │
# │ ---        ┆ str     ┆ ---       ┆ ---       ┆   ┆ ---       ┆ Y         ┆ ---       ┆ date      │
# │ i64        ┆         ┆ i64       ┆ str       ┆   ┆ i64       ┆ ---       ┆ i64       ┆           │
# │            ┆         ┆           ┆           ┆   ┆           ┆ i64       ┆           ┆           │
# ╞════════════╪═════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 4          ┆ AS      ┆ 98        ┆ N407AS    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2015-01-0 │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1         │
# │ 4          ┆ AA      ┆ 2336      ┆ N3KUAA    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2015-01-0 │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1         │
# │ 4          ┆ US      ┆ 840       ┆ N171US    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2015-01-0 │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1         │
# │ 4          ┆ AA      ┆ 258       ┆ N3HYAA    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2015-01-0 │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1         │
# │ 4          ┆ AS      ┆ 135       ┆ N527AS    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2015-01-0 │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1         │
# └────────────┴─────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### change day of the week to weekdays

# %%
day_dict = {1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday', 7: 'Sunday'}
flight_df = flight_df.with_columns(pl.col("DAY_OF_WEEK").replace(day_dict))

# %%
flight_df.head()
# Out:
# shape: (5, 29)
# ┌────────────┬─────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NU ┆ TAIL_NUMB ┆ … ┆ AIRLINE_D ┆ LATE_AIRC ┆ WEATHER_D ┆ DATE      │
# │ K          ┆ ---     ┆ MBER      ┆ ER        ┆   ┆ ELAY      ┆ RAFT_DELA ┆ ELAY      ┆ ---       │
# │ ---        ┆ str     ┆ ---       ┆ ---       ┆   ┆ ---       ┆ Y         ┆ ---       ┆ date      │
# │ str        ┆         ┆ i64       ┆ str       ┆   ┆ i64       ┆ ---       ┆ i64       ┆           │
# │            ┆         ┆           ┆           ┆   ┆           ┆ i64       ┆           ┆           │
# ╞════════════╪═════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Thursday   ┆ AS      ┆ 98        ┆ N407AS    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2015-01-0 │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1         │
# │ Thursday   ┆ AA      ┆ 2336      ┆ N3KUAA    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2015-01-0 │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1         │
# │ Thursday   ┆ US      ┆ 840       ┆ N171US    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2015-01-0 │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1         │
# │ Thursday   ┆ AA      ┆ 258       ┆ N3HYAA    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2015-01-0 │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1         │
# │ Thursday   ┆ AS      ┆ 135       ┆ N527AS    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2015-01-0 │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1         │
# └────────────┴─────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Tail Number

# %%
flight_df = flight_df.group_by('AIRLINE').map_groups(
    lambda df: df.with_columns(
        df['TAIL_NUMBER'].fill_null(strategy="forward"))
    )

# %% [markdown]
# ### Drop the remaining missing rows

# %%
flight_df.null_count()
# Out:
# shape: (1, 29)
# ┌────────────┬─────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬──────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NUM ┆ TAIL_NUMBE ┆ … ┆ AIRLINE_DE ┆ LATE_AIRCR ┆ WEATHER_DE ┆ DATE │
# │ K          ┆ ---     ┆ BER        ┆ R          ┆   ┆ LAY        ┆ AFT_DELAY  ┆ LAY        ┆ ---  │
# │ ---        ┆ u32     ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---        ┆ u32  │
# │ u32        ┆         ┆ u32        ┆ u32        ┆   ┆ u32        ┆ u32        ┆ u32        ┆      │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪══════╡
# │ 0          ┆ 0       ┆ 0          ┆ 0          ┆ … ┆ 4755640    ┆ 4755640    ┆ 4755640    ┆ 0    │
# └────────────┴─────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴──────┘

# %%
cancellation_df = flight_df.drop

# %%
def format_time(val):
    if val is None:
        return None
    elif val == 2400:
        val = 0
    val_str = f"{val:04d}"
    return time(int(val_str[0:2]), int(val_str[2:4]))

# Apply the conversions
flight_df = flight_df.with_columns([
    pl.col('DATE'),
    pl.col('SCHEDULED_DEPARTURE').map_elements(format_time).alias('SCHEDULED_DEPARTURE_DATETIME'),
    pl.col('DEPARTURE_TIME').map_elements(format_time).alias('DEPARTURE_TIME_DATETIME'),
    pl.col('SCHEDULED_ARRIVAL').map_elements(format_time).alias('SCHEDULED_ARRIVAL_DATETIME'),
    pl.col('ARRIVAL_TIME').map_elements(format_time).alias('ARRIVAL_TIME_DATETIME')
])
# Display the results
flight_df.head(10)
# Out:
# shape: (5, 33)
# ┌────────────┬─────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NU ┆ TAIL_NUMB ┆ … ┆ SCHEDULED ┆ DEPARTURE ┆ SCHEDULED ┆ ARRIVAL_T │
# │ K          ┆ ---     ┆ MBER      ┆ ER        ┆   ┆ _DEPARTUR ┆ _TIME_DAT ┆ _ARRIVAL_ ┆ IME_DATET │
# │ ---        ┆ str     ┆ ---       ┆ ---       ┆   ┆ E_DATETIM ┆ ETIME     ┆ DATETIME  ┆ IME       │
# │ str        ┆         ┆ i64       ┆ str       ┆   ┆ E         ┆ ---       ┆ ---       ┆ ---       │
# │            ┆         ┆           ┆           ┆   ┆ ---       ┆ time      ┆ time      ┆ time      │
# │            ┆         ┆           ┆           ┆   ┆ time      ┆           ┆           ┆           │
# ╞════════════╪═════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Thursday   ┆ DL      ┆ 806       ┆ N3730B    ┆ … ┆ 00:25:00  ┆ 00:20:00  ┆ 06:02:00  ┆ 06:10:00  │
# │ Thursday   ┆ DL      ┆ 1173      ┆ N826DN    ┆ … ┆ 00:30:00  ┆ 00:33:00  ┆ 07:11:00  ┆ 06:56:00  │
# │ Thursday   ┆ DL      ┆ 2336      ┆ N958DN    ┆ … ┆ 00:30:00  ┆ 00:24:00  ┆ 05:23:00  ┆ 04:53:00  │
# │ Thursday   ┆ DL      ┆ 1434      ┆ N547US    ┆ … ┆ 00:35:00  ┆ 00:35:00  ┆ 06:09:00  ┆ 06:05:00  │
# │ Thursday   ┆ DL      ┆ 2324      ┆ N3751B    ┆ … ┆ 00:40:00  ┆ 00:34:00  ┆ 06:15:00  ┆ 05:53:00  │
# └────────────┴─────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
flight_df.head()
# Out:
# shape: (5, 33)
# ┌────────────┬─────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NU ┆ TAIL_NUMB ┆ … ┆ SCHEDULED ┆ DEPARTURE ┆ SCHEDULED ┆ ARRIVAL_T │
# │ K          ┆ ---     ┆ MBER      ┆ ER        ┆   ┆ _DEPARTUR ┆ _TIME_DAT ┆ _ARRIVAL_ ┆ IME_DATET │
# │ ---        ┆ str     ┆ ---       ┆ ---       ┆   ┆ E_DATETIM ┆ ETIME     ┆ DATETIME  ┆ IME       │
# │ str        ┆         ┆ i64       ┆ str       ┆   ┆ E         ┆ ---       ┆ ---       ┆ ---       │
# │            ┆         ┆           ┆           ┆   ┆ ---       ┆ time      ┆ time      ┆ time      │
# │            ┆         ┆           ┆           ┆   ┆ time      ┆           ┆           ┆           │
# ╞════════════╪═════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Thursday   ┆ DL      ┆ 806       ┆ N3730B    ┆ … ┆ 00:25:00  ┆ 00:20:00  ┆ 06:02:00  ┆ 06:10:00  │
# │ Thursday   ┆ DL      ┆ 1173      ┆ N826DN    ┆ … ┆ 00:30:00  ┆ 00:33:00  ┆ 07:11:00  ┆ 06:56:00  │
# │ Thursday   ┆ DL      ┆ 2336      ┆ N958DN    ┆ … ┆ 00:30:00  ┆ 00:24:00  ┆ 05:23:00  ┆ 04:53:00  │
# │ Thursday   ┆ DL      ┆ 1434      ┆ N547US    ┆ … ┆ 00:35:00  ┆ 00:35:00  ┆ 06:09:00  ┆ 06:05:00  │
# │ Thursday   ┆ DL      ┆ 2324      ┆ N3751B    ┆ … ┆ 00:40:00  ┆ 00:34:00  ┆ 06:15:00  ┆ 05:53:00  │
# └────────────┴─────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
flight_df.shape
# Out:
# (5819079, 33)

# %% [markdown]
# # Feature Engineering- creating new features

# %% [markdown]
# DEPARTURE INDEX

# %%
flight_df = flight_df.with_columns((pl.col('DEPARTURE_TIME') / pl.col('SCHEDULED_DEPARTURE')).alias('DEPARTURE_INDEX'))
flight_df.head()
# Out:
# shape: (5, 34)
# ┌────────────┬─────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NU ┆ TAIL_NUMB ┆ … ┆ DEPARTURE ┆ SCHEDULED ┆ ARRIVAL_T ┆ DEPARTURE │
# │ K          ┆ ---     ┆ MBER      ┆ ER        ┆   ┆ _TIME_DAT ┆ _ARRIVAL_ ┆ IME_DATET ┆ _INDEX    │
# │ ---        ┆ str     ┆ ---       ┆ ---       ┆   ┆ ETIME     ┆ DATETIME  ┆ IME       ┆ ---       │
# │ str        ┆         ┆ i64       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ f64       │
# │            ┆         ┆           ┆           ┆   ┆ time      ┆ time      ┆ time      ┆           │
# ╞════════════╪═════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Thursday   ┆ DL      ┆ 806       ┆ N3730B    ┆ … ┆ 00:20:00  ┆ 06:02:00  ┆ 06:10:00  ┆ 0.8       │
# │ Thursday   ┆ DL      ┆ 1173      ┆ N826DN    ┆ … ┆ 00:33:00  ┆ 07:11:00  ┆ 06:56:00  ┆ 1.1       │
# │ Thursday   ┆ DL      ┆ 2336      ┆ N958DN    ┆ … ┆ 00:24:00  ┆ 05:23:00  ┆ 04:53:00  ┆ 0.8       │
# │ Thursday   ┆ DL      ┆ 1434      ┆ N547US    ┆ … ┆ 00:35:00  ┆ 06:09:00  ┆ 06:05:00  ┆ 1.0       │
# │ Thursday   ┆ DL      ┆ 2324      ┆ N3751B    ┆ … ┆ 00:34:00  ┆ 06:15:00  ┆ 05:53:00  ┆ 0.85      │
# └────────────┴─────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ARRIVAL INDEX

# %%
flight_df = flight_df.with_columns((pl.col('ARRIVAL_TIME') / pl.col('SCHEDULED_ARRIVAL')).alias('ARRIVAL_INDEX'))

# %% [markdown]
# Total Delay

# %%
flight_df_new = flight_df.with_columns(pl.col("DEPARTURE_DELAY") + pl.col("ARRIVAL_DELAY").alias("TOTAL_DELAY"))

flight_df_new.head(10)
# Out:
# shape: (10, 35)
# ┌────────────┬─────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NU ┆ TAIL_NUMB ┆ … ┆ SCHEDULED ┆ ARRIVAL_T ┆ DEPARTURE ┆ ARRIVAL_I │
# │ K          ┆ ---     ┆ MBER      ┆ ER        ┆   ┆ _ARRIVAL_ ┆ IME_DATET ┆ _INDEX    ┆ NDEX      │
# │ ---        ┆ str     ┆ ---       ┆ ---       ┆   ┆ DATETIME  ┆ IME       ┆ ---       ┆ ---       │
# │ str        ┆         ┆ i64       ┆ str       ┆   ┆ ---       ┆ ---       ┆ f64       ┆ f64       │
# │            ┆         ┆           ┆           ┆   ┆ time      ┆ time      ┆           ┆           │
# ╞════════════╪═════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Thursday   ┆ DL      ┆ 806       ┆ N3730B    ┆ … ┆ 06:02:00  ┆ 06:10:00  ┆ 0.8       ┆ 1.013289  │
# │ Thursday   ┆ DL      ┆ 1173      ┆ N826DN    ┆ … ┆ 07:11:00  ┆ 06:56:00  ┆ 1.1       ┆ 0.922644  │
# │ Thursday   ┆ DL      ┆ 2336      ┆ N958DN    ┆ … ┆ 05:23:00  ┆ 04:53:00  ┆ 0.8       ┆ 0.866157  │
# │ Thursday   ┆ DL      ┆ 1434      ┆ N547US    ┆ … ┆ 06:09:00  ┆ 06:05:00  ┆ 1.0       ┆ 0.993432  │
# │ …          ┆ …       ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ Thursday   ┆ DL      ┆ 1560      ┆ N3743H    ┆ … ┆ 05:15:00  ┆ 04:51:00  ┆ 0.688889  ┆ 0.875728  │
# │ Thursday   ┆ DL      ┆ 1670      ┆ N806DN    ┆ … ┆ 06:03:00  ┆ 05:51:00  ┆ 0.9       ┆ 0.913765  │
# │ Thursday   ┆ DL      ┆ 1450      ┆ N671DN    ┆ … ┆ 06:08:00  ┆ 05:45:00  ┆ 0.971429  ┆ 0.896382  │
# │ Thursday   ┆ DL      ┆ 95        ┆ N320US    ┆ … ┆ 07:15:00  ┆ 07:25:00  ┆ 0.957143  ┆ 1.013986  │
# └────────────┴─────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ROUTE

# %%
flight_df = flight_df.with_columns((pl.col("ORIGIN_AIRPORT") + "-" + pl.col("DESTINATION_AIRPORT")).alias("ROUTE"))

flight_df.head()
# Out:
# shape: (5, 36)
# ┌────────────┬─────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬─────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NUM ┆ TAIL_NUMBE ┆ … ┆ ARRIVAL_T ┆ DEPARTURE ┆ ARRIVAL_I ┆ ROUTE   │
# │ K          ┆ ---     ┆ BER        ┆ R          ┆   ┆ IME_DATET ┆ _INDEX    ┆ NDEX      ┆ ---     │
# │ ---        ┆ str     ┆ ---        ┆ ---        ┆   ┆ IME       ┆ ---       ┆ ---       ┆ str     │
# │ str        ┆         ┆ i64        ┆ str        ┆   ┆ ---       ┆ f64       ┆ f64       ┆         │
# │            ┆         ┆            ┆            ┆   ┆ time      ┆           ┆           ┆         │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═════════╡
# │ Thursday   ┆ DL      ┆ 806        ┆ N3730B     ┆ … ┆ 06:10:00  ┆ 0.8       ┆ 1.013289  ┆ SFO-MSP │
# │ Thursday   ┆ DL      ┆ 1173       ┆ N826DN     ┆ … ┆ 06:56:00  ┆ 1.1       ┆ 0.922644  ┆ LAS-ATL │
# │ Thursday   ┆ DL      ┆ 2336       ┆ N958DN     ┆ … ┆ 04:53:00  ┆ 0.8       ┆ 0.866157  ┆ DEN-ATL │
# │ Thursday   ┆ DL      ┆ 1434       ┆ N547US     ┆ … ┆ 06:05:00  ┆ 1.0       ┆ 0.993432  ┆ LAX-MSP │
# │ Thursday   ┆ DL      ┆ 2324       ┆ N3751B     ┆ … ┆ 05:53:00  ┆ 0.85      ┆ 0.899187  ┆ SLC-ATL │
# └────────────┴─────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴─────────┘

# %% [markdown]
# TIME OF DAY_FOR_DEPARTURE AND ARRIVAL

# %%
flight_df.columns
# Out:
# ['DAY_OF_WEEK',
#  'AIRLINE',
#  'FLIGHT_NUMBER',
#  'TAIL_NUMBER',
#  'ORIGIN_AIRPORT',
#  'DESTINATION_AIRPORT',
#  'SCHEDULED_DEPARTURE',
#  'DEPARTURE_TIME',
#  'DEPARTURE_DELAY',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'SCHEDULED_TIME',
#  'ELAPSED_TIME',
#  'AIR_TIME',
#  'DISTANCE',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'SCHEDULED_ARRIVAL',
#  'ARRIVAL_TIME',
#  'ARRIVAL_DELAY',
#  'DIVERTED',
#  'CANCELLED',
#  'CANCELLATION_REASON',
#  'AIR_SYSTEM_DELAY',
#  'SECURITY_DELAY',
#  'AIRLINE_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'WEATHER_DELAY',
#  'DATE',
#  'SCHEDULED_DEPARTURE_DATETIME',
#  'DEPARTURE_TIME_DATETIME',
#  'SCHEDULED_ARRIVAL_DATETIME',
#  'ARRIVAL_TIME_DATETIME',
#  'DEPARTURE_INDEX',
#  'ARRIVAL_INDEX',
#  'ROUTE']

# %%
def get_time_of_day(t):
    if t >= time(6, 0) and t <= time(11, 59):
        return "Morning"
    elif t >= time(12, 0) and t <= time(17, 59):
        return "Afternoon"
    elif t >= time(18, 0) and t <= time(23, 59):
        return "Evening"
    else:
        return "Night"

flight_df = flight_df.with_columns(
   pl.col('DEPARTURE_TIME_DATETIME').map_elements(get_time_of_day).alias('TIME_OF_DAY_FOR_DEPARTURE')
)
print(flight_df)
# Out:
# shape: (5_819_079, 37)
# ┌────────────┬─────────┬────────────┬────────────┬───┬───────────┬───────────┬─────────┬───────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NUM ┆ TAIL_NUMBE ┆ … ┆ DEPARTURE ┆ ARRIVAL_I ┆ ROUTE   ┆ TIME_OF_D │
# │ K          ┆ ---     ┆ BER        ┆ R          ┆   ┆ _INDEX    ┆ NDEX      ┆ ---     ┆ AY_FOR_DE │
# │ ---        ┆ str     ┆ ---        ┆ ---        ┆   ┆ ---       ┆ ---       ┆ str     ┆ PARTURE   │
# │ str        ┆         ┆ i64        ┆ str        ┆   ┆ f64       ┆ f64       ┆         ┆ ---       │
# │            ┆         ┆            ┆            ┆   ┆           ┆           ┆         ┆ str       │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═════════╪═══════════╡
# │ Thursday   ┆ DL      ┆ 806        ┆ N3730B     ┆ … ┆ 0.8       ┆ 1.013289  ┆ SFO-MSP ┆ Night     │
# │ Thursday   ┆ DL      ┆ 1173       ┆ N826DN     ┆ … ┆ 1.1       ┆ 0.922644  ┆ LAS-ATL ┆ Night     │
# │ Thursday   ┆ DL      ┆ 2336       ┆ N958DN     ┆ … ┆ 0.8       ┆ 0.866157  ┆ DEN-ATL ┆ Night     │
# │ Thursday   ┆ DL      ┆ 1434       ┆ N547US     ┆ … ┆ 1.0       ┆ 0.993432  ┆ LAX-MSP ┆ Night     │
# │ …          ┆ …       ┆ …          ┆ …          ┆ … ┆ …         ┆ …         ┆ …       ┆ …         │
# │ Thursday   ┆ VX      ┆ 357        ┆ N284VA     ┆ … ┆ 0.994621  ┆ 0.979556  ┆ BOS-SFO ┆ Evening   │
# │ Thursday   ┆ VX      ┆ 1916       ┆ N853VA     ┆ … ┆ 0.996392  ┆ 0.972512  ┆ SFO-LAS ┆ Evening   │
# │ Thursday   ┆ VX      ┆ 490        ┆ N840VA     ┆ … ┆ 0.998974  ┆ 0.994647  ┆ LAX-LAS ┆ Evening   │
# │ Thursday   ┆ VX      ┆ 48         ┆ N281VA     ┆ … ┆ 0.999138  ┆ 0.8768    ┆ OGG-SFO ┆ Evening   │
# └────────────┴─────────┴────────────┴────────────┴───┴───────────┴───────────┴─────────┴───────────┘

# %%
flight_df = flight_df.with_columns(
   pl.col('ARRIVAL_TIME_DATETIME').map_elements(get_time_of_day).alias('TIME_OF_DAY_FOR_ARRIVAL')
)
print(flight_df)
# Out:
# shape: (5_819_079, 38)
# ┌────────────┬─────────┬────────────┬────────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NUM ┆ TAIL_NUMBE ┆ … ┆ ARRIVAL_I ┆ ROUTE   ┆ TIME_OF_D ┆ TIME_OF_D │
# │ K          ┆ ---     ┆ BER        ┆ R          ┆   ┆ NDEX      ┆ ---     ┆ AY_FOR_DE ┆ AY_FOR_AR │
# │ ---        ┆ str     ┆ ---        ┆ ---        ┆   ┆ ---       ┆ str     ┆ PARTURE   ┆ RIVAL     │
# │ str        ┆         ┆ i64        ┆ str        ┆   ┆ f64       ┆         ┆ ---       ┆ ---       │
# │            ┆         ┆            ┆            ┆   ┆           ┆         ┆ str       ┆ str       │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ Thursday   ┆ DL      ┆ 806        ┆ N3730B     ┆ … ┆ 1.013289  ┆ SFO-MSP ┆ Night     ┆ Morning   │
# │ Thursday   ┆ DL      ┆ 1173       ┆ N826DN     ┆ … ┆ 0.922644  ┆ LAS-ATL ┆ Night     ┆ Morning   │
# │ Thursday   ┆ DL      ┆ 2336       ┆ N958DN     ┆ … ┆ 0.866157  ┆ DEN-ATL ┆ Night     ┆ Night     │
# │ Thursday   ┆ DL      ┆ 1434       ┆ N547US     ┆ … ┆ 0.993432  ┆ LAX-MSP ┆ Night     ┆ Morning   │
# │ …          ┆ …       ┆ …          ┆ …          ┆ … ┆ …         ┆ …       ┆ …         ┆ …         │
# │ Thursday   ┆ VX      ┆ 357        ┆ N284VA     ┆ … ┆ 0.979556  ┆ BOS-SFO ┆ Evening   ┆ Evening   │
# │ Thursday   ┆ VX      ┆ 1916       ┆ N853VA     ┆ … ┆ 0.972512  ┆ SFO-LAS ┆ Evening   ┆ Evening   │
# │ Thursday   ┆ VX      ┆ 490        ┆ N840VA     ┆ … ┆ 0.994647  ┆ LAX-LAS ┆ Evening   ┆ Evening   │
# │ Thursday   ┆ VX      ┆ 48         ┆ N281VA     ┆ … ┆ 0.8768    ┆ OGG-SFO ┆ Evening   ┆ Night     │
# └────────────┴─────────┴────────────┴────────────┴───┴───────────┴─────────┴───────────┴───────────┘

# %% [markdown]
# SPEED IN AIRPLANE

# %%
flight_df = flight_df.with_columns((pl.col('DISTANCE') / (pl.col('ELAPSED_TIME')/60)).alias('SPEED_OF_AIRPLANE'))

# %% [markdown]
# SEASONAL INDICATOR

# %%
def get_season(date):
    month = date.month
    if 3 <= month <= 5:
        return "Spring"
    elif 6 <= month <= 8:
        return "Summer"
    elif 9 <= month <= 11:
        return "Autumn"
    else:
        return "Winter"

flight_df = flight_df.with_columns(
   pl.col('DATE').map_elements(get_season).alias('SEASON'),
)
print(flight_df)
# Out:
# shape: (5_819_079, 40)
# ┌────────────┬─────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NUM ┆ TAIL_NUMBE ┆ … ┆ TIME_OF_DA ┆ TIME_OF_D ┆ SPEED_OF_ ┆ SEASON │
# │ K          ┆ ---     ┆ BER        ┆ R          ┆   ┆ Y_FOR_DEPA ┆ AY_FOR_AR ┆ AIRPLANE  ┆ ---    │
# │ ---        ┆ str     ┆ ---        ┆ ---        ┆   ┆ RTURE      ┆ RIVAL     ┆ ---       ┆ str    │
# │ str        ┆         ┆ i64        ┆ str        ┆   ┆ ---        ┆ ---       ┆ f64       ┆        │
# │            ┆         ┆            ┆            ┆   ┆ str        ┆ str       ┆           ┆        │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪════════╡
# │ Thursday   ┆ DL      ┆ 806        ┆ N3730B     ┆ … ┆ Night      ┆ Morning   ┆ 414.52173 ┆ Winter │
# │            ┆         ┆            ┆            ┆   ┆            ┆           ┆ 9         ┆        │
# │ Thursday   ┆ DL      ┆ 1173       ┆ N826DN     ┆ … ┆ Night      ┆ Morning   ┆ 516.35468 ┆ Winter │
# │ Thursday   ┆ DL      ┆ 2336       ┆ N958DN     ┆ … ┆ Night      ┆ Night     ┆ 482.81879 ┆ Winter │
# │            ┆         ┆            ┆            ┆   ┆            ┆           ┆ 2         ┆        │
# │ Thursday   ┆ DL      ┆ 1434       ┆ N547US     ┆ … ┆ Night      ┆ Morning   ┆ 438.57142 ┆ Winter │
# │            ┆         ┆            ┆            ┆   ┆            ┆           ┆ 9         ┆        │
# │ …          ┆ …       ┆ …          ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …      │
# │ Thursday   ┆ VX      ┆ 357        ┆ N284VA     ┆ … ┆ Evening    ┆ Evening   ┆ 432.64    ┆ Winter │
# │ Thursday   ┆ VX      ┆ 1916       ┆ N853VA     ┆ … ┆ Evening    ┆ Evening   ┆ 314.43038 ┆ Winter │
# │ Thursday   ┆ VX      ┆ 490        ┆ N840VA     ┆ … ┆ Evening    ┆ Evening   ┆ 252.85714 ┆ Winter │
# │            ┆         ┆            ┆            ┆   ┆            ┆           ┆ 3         ┆        │
# │ Thursday   ┆ VX      ┆ 48         ┆ N281VA     ┆ … ┆ Evening    ┆ Night     ┆ 519.55555 ┆ Winter │
# │            ┆         ┆            ┆            ┆   ┆            ┆           ┆ 6         ┆        │
# └────────────┴─────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴────────┘

# %%
flight_df.head(10)
# Out:
# shape: (10, 40)
# ┌────────────┬─────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NUM ┆ TAIL_NUMBE ┆ … ┆ TIME_OF_DA ┆ TIME_OF_D ┆ SPEED_OF_ ┆ SEASON │
# │ K          ┆ ---     ┆ BER        ┆ R          ┆   ┆ Y_FOR_DEPA ┆ AY_FOR_AR ┆ AIRPLANE  ┆ ---    │
# │ ---        ┆ str     ┆ ---        ┆ ---        ┆   ┆ RTURE      ┆ RIVAL     ┆ ---       ┆ str    │
# │ str        ┆         ┆ i64        ┆ str        ┆   ┆ ---        ┆ ---       ┆ f64       ┆        │
# │            ┆         ┆            ┆            ┆   ┆ str        ┆ str       ┆           ┆        │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪════════╡
# │ Thursday   ┆ DL      ┆ 806        ┆ N3730B     ┆ … ┆ Night      ┆ Morning   ┆ 414.52173 ┆ Winter │
# │            ┆         ┆            ┆            ┆   ┆            ┆           ┆ 9         ┆        │
# │ Thursday   ┆ DL      ┆ 1173       ┆ N826DN     ┆ … ┆ Night      ┆ Morning   ┆ 516.35468 ┆ Winter │
# │ Thursday   ┆ DL      ┆ 2336       ┆ N958DN     ┆ … ┆ Night      ┆ Night     ┆ 482.81879 ┆ Winter │
# │            ┆         ┆            ┆            ┆   ┆            ┆           ┆ 2         ┆        │
# │ Thursday   ┆ DL      ┆ 1434       ┆ N547US     ┆ … ┆ Night      ┆ Morning   ┆ 438.57142 ┆ Winter │
# │            ┆         ┆            ┆            ┆   ┆            ┆           ┆ 9         ┆        │
# │ …          ┆ …       ┆ …          ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …      │
# │ Thursday   ┆ DL      ┆ 1560       ┆ N3743H     ┆ … ┆ Night      ┆ Night     ┆ 434.4     ┆ Winter │
# │ Thursday   ┆ DL      ┆ 1670       ┆ N806DN     ┆ … ┆ Night      ┆ Night     ┆ 460.0     ┆ Winter │
# │ Thursday   ┆ DL      ┆ 1450       ┆ N671DN     ┆ … ┆ Night      ┆ Night     ┆ 478.15950 ┆ Winter │
# │            ┆         ┆            ┆            ┆   ┆            ┆           ┆ 9         ┆        │
# │ Thursday   ┆ DL      ┆ 95         ┆ N320US     ┆ … ┆ Night      ┆ Morning   ┆ 412.98701 ┆ Winter │
# │            ┆         ┆            ┆            ┆   ┆            ┆           ┆ 3         ┆        │
# └────────────┴─────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴────────┘

# %% [markdown]
# MEAN MEDIAN MODE

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## Univariate Analysis

# %%
flight_df_pd = flight_df.to_pandas()

# %% [markdown]
# MOST USED AIRLINE

# %%
frequency = flight_df_pd['AIRLINE'].value_counts()
print(frequency)
plt.figure(figsize=(10, 6))
sns.countplot(x=flight_df_pd['AIRLINE'])
plt.title('Flight Counts by Airline')
plt.ylabel('Count')
plt.xlabel('Airline')
plt.show()
# Out:
# WN    1261855
# DL     875881
# AA     725984
# OO     588353
# EV     571977
# UA     515723
# MQ     294632
# B6     267048
# US     198715
# AS     172521
# NK     117379
# F9      90836
# HA      76272
# VX      61903
# Name: AIRLINE, dtype: int64

# %%
categorical_columns = ['DAY_OF_WEEK','SEASON']

for col in categorical_columns:
    frequency = flight_df_pd[col].value_counts()
    print(frequency.head(5))
    plt.figure(figsize=(10, 6))
    sns.countplot(y=col, data=flight_df_pd, order=flight_df_pd[col].value_counts().index)
    plt.title(f'Frequency of Flights - {col}')
    plt.xlabel('Frequency')
    plt.ylabel(col)
    plt.show()
# Out:
# Thursday     872521
# Monday       865543
# Friday       862209
# Wednesday    855897
# Tuesday      844600
# Name: DAY_OF_WEEK, dtype: int64
# Summer    1535151
# Spring    1486456
# Autumn    1419083
# Winter    1378389
# Name: SEASON, dtype: int64

# %%
categorical_columns = ['ROUTE']

for col in categorical_columns:
    frequency = flight_df_pd[col].value_counts().head(10)
    print(f"Frequency count for {col}:\n{frequency}\n")

    plt.figure(figsize=(10, 6))
    sns.countplot(y=col, data=flight_df_pd, order=flight_df_pd[col].value_counts().head(10).index)
    plt.title(f'Frequency of Flights - {col}')
    plt.xlabel('Frequency')
    plt.ylabel(col)
    plt.show()

# it will be better to put more effort into SFO-LAX since there revenue comes from there the most
# Out:
# Frequency count for ROUTE:
# SFO-LAX    13744
# LAX-SFO    13457
# JFK-LAX    12016
# LAX-JFK    12015
# LAS-LAX     9715
# LGA-ORD     9639
# LAX-LAS     9594
# ORD-LGA     9575
# SFO-JFK     8440
# JFK-SFO     8437
# Name: ROUTE, dtype: int64

# %%
cancelled_flights = flight_df_pd[flight_df_pd['CANCELLED'] == 1]

plt.figure(figsize=(10, 6))
sns.countplot(y='CANCELLATION_REASON', data=cancelled_flights)
plt.title('Cancellation Reasons')
plt.xlabel('Count')
plt.ylabel('Reason')
plt.show()

# %%
labels = [s for s in flight_df_pd['AIRLINE'].unique()]
sizes = flight_df_pd['AIRLINE'].value_counts().values
explode = [0.3 if sizes[i] < 20000 else 0.0 for i in range(len(labels))]

fig, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.0f%%',
                                    shadow=False, startangle=0)

for i in range(len(labels)):
    texts[i].set_fontsize(14)

ax1.axis('equal')
ax1.set_title('% of flights per company',
              color='w', fontsize=12)

plt.show()

# %%
flight_df.columns
# Out:
# ['DAY_OF_WEEK',
#  'AIRLINE',
#  'FLIGHT_NUMBER',
#  'TAIL_NUMBER',
#  'ORIGIN_AIRPORT',
#  'DESTINATION_AIRPORT',
#  'SCHEDULED_DEPARTURE',
#  'DEPARTURE_TIME',
#  'DEPARTURE_DELAY',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'SCHEDULED_TIME',
#  'ELAPSED_TIME',
#  'AIR_TIME',
#  'DISTANCE',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'SCHEDULED_ARRIVAL',
#  'ARRIVAL_TIME',
#  'ARRIVAL_DELAY',
#  'DIVERTED',
#  'CANCELLED',
#  'CANCELLATION_REASON',
#  'AIR_SYSTEM_DELAY',
#  'SECURITY_DELAY',
#  'AIRLINE_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'WEATHER_DELAY',
#  'DATE',
#  'SCHEDULED_DEPARTURE_DATETIME',
#  'DEPARTURE_TIME_DATETIME',
#  'SCHEDULED_ARRIVAL_DATETIME',
#  'ARRIVAL_TIME_DATETIME',
#  'DEPARTURE_INDEX',
#  'ARRIVAL_INDEX',
#  'ROUTE',
#  'TIME_OF_DAY_FOR_DEPARTURE',
#  'TIME_OF_DAY_FOR_ARRIVAL',
#  'SPEED_OF_AIRPLANE',
#  'SEASON']

# %% [markdown]
# FREQUENCY OF FLIGHT BY MONTH

# %%
df = flight_df.with_columns(pl.col('DATE').dt.month().alias('MONTH'))


frequency_by_month = df.group_by('MONTH').agg([
    pl.count('FLIGHT_NUMBER').alias('FREQUENCY')
])
print(frequency_by_month)
frequency_by_month_pd = frequency_by_month.to_pandas()


colors = ['red', 'green', 'blue', 'yellow', 'purple', 'orange', 
          'pink', 'brown', 'grey', 'cyan', 'magenta', 'lime']

plt.figure(figsize=(10, 6))
plt.bar(frequency_by_month_pd['MONTH'], frequency_by_month_pd['FREQUENCY'], color=colors)
plt.xlabel('Month')
plt.ylabel('Frequency of Flights')
plt.title('Frequency of Flights by Month')
plt.xticks(range(1, 13)) 
plt.show()
# Out:
# shape: (12, 2)
# ┌───────┬───────────┐
# │ MONTH ┆ FREQUENCY │
# │ ---   ┆ ---       │
# │ i8    ┆ u32       │
# ╞═══════╪═══════════╡
# │ 3     ┆ 504312    │
# │ 6     ┆ 503897    │
# │ 12    ┆ 479230    │
# │ 9     ┆ 464946    │
# │ …     ┆ …         │
# │ 8     ┆ 510536    │
# │ 2     ┆ 429191    │
# │ 5     ┆ 496993    │
# │ 11    ┆ 467972    │
# └───────┴───────────┘

# %%
frequency_by_month.head(12)
# Out:
# shape: (12, 2)
# ┌───────┬───────────┐
# │ MONTH ┆ FREQUENCY │
# │ ---   ┆ ---       │
# │ i8    ┆ u32       │
# ╞═══════╪═══════════╡
# │ 3     ┆ 504312    │
# │ 6     ┆ 503897    │
# │ 12    ┆ 479230    │
# │ 9     ┆ 464946    │
# │ …     ┆ …         │
# │ 8     ┆ 510536    │
# │ 2     ┆ 429191    │
# │ 5     ┆ 496993    │
# │ 11    ┆ 467972    │
# └───────┴───────────┘

# %%
diverted_proportion = flight_df['DIVERTED'].value_counts()
cancelled_proportion = flight_df['CANCELLED'].value_counts()

# Print results
print(f"Proportion of Diverted Flights: {diverted_proportion}%")
print(f"Proportion of Cancelled Flights: {cancelled_proportion}%")
# Out:
# Proportion of Diverted Flights: shape: (2, 2)
# ┌──────────┬─────────┐
# │ DIVERTED ┆ count   │
# │ ---      ┆ ---     │
# │ i64      ┆ u32     │
# ╞══════════╪═════════╡
# │ 0        ┆ 5803892 │
# │ 1        ┆ 15187   │
# └──────────┴─────────┘%
# Proportion of Cancelled Flights: shape: (2, 2)
# ┌───────────┬─────────┐
# │ CANCELLED ┆ count   │
# │ ---       ┆ ---     │
# │ i64       ┆ u32     │
# ╞═══════════╪═════════╡
# │ 0         ┆ 5729195 │
# │ 1         ┆ 89884   │
# └───────────┴─────────┘%

# %%
if 'TOTAL_DELAY' not in flight_df.columns:
    flight_df = flight_df.with_columns((pl.col('DEPARTURE_DELAY') + pl.col('ARRIVAL_DELAY')).alias('TOTAL_DELAY'))

# Highest and Lowest Departure Delay
highest_departure_delay = flight_df.select(pl.max('DEPARTURE_DELAY')).to_numpy()[0][0]
lowest_departure_delay = flight_df.select(pl.min('DEPARTURE_DELAY')).to_numpy()[0][0]

# Highest and Lowest Arrival Delay
highest_arrival_delay = flight_df.select(pl.max('ARRIVAL_DELAY')).to_numpy()[0][0]
lowest_arrival_delay = flight_df.select(pl.min('ARRIVAL_DELAY')).to_numpy()[0][0]

# Mean and Median of Total Delay
mean_total_delay = flight_df.select(pl.mean('TOTAL_DELAY')).to_numpy()[0][0]
median_total_delay = flight_df.select(pl.median('TOTAL_DELAY')).to_numpy()[0][0]

# Mode of Total Delay (requires converting to pandas)
mode_total_delay = flight_df.to_pandas()['TOTAL_DELAY'].mode()[0]

# Print results
print(f"Highest Departure Delay: {highest_departure_delay}")
print(f"Lowest Departure Delay: {lowest_departure_delay}")
print(f"Highest Arrival Delay: {highest_arrival_delay}")
print(f"Lowest Arrival Delay: {lowest_arrival_delay}")
print(f"Mean Total Delay: {mean_total_delay}")
print(f"Median Total Delay: {median_total_delay}")
print(f"Mode of Total Delay: {mode_total_delay}")
# Out:
# Highest Departure Delay: 1988
# Lowest Departure Delay: -82
# Highest Arrival Delay: 1971
# Lowest Arrival Delay: -87
# Mean Total Delay: 13.701899262304147
# Median Total Delay: -7.0
# Mode of Total Delay: -13.0

# %%
percent_cancelled = flight_df['CANCELLED'].mean() * 100

# Calculate the percentage of diverted flights
percent_diverted = flight_df['DIVERTED'].mean() * 100

print(f"Percentage of Cancelled Flights: {percent_cancelled:.2f}%")
print(f"Percentage of Diverted Flights: {percent_diverted:.2f}%")
# Out:
# Percentage of Cancelled Flights: 1.54%
# Percentage of Diverted Flights: 0.26%

# %%
flight_df.head()
# Out:
# shape: (5, 41)
# ┌────────────┬─────────┬────────────┬────────────┬───┬────────────┬───────────┬────────┬───────────┐
# │ DAY_OF_WEE ┆ AIRLINE ┆ FLIGHT_NUM ┆ TAIL_NUMBE ┆ … ┆ TIME_OF_DA ┆ SPEED_OF_ ┆ SEASON ┆ TOTAL_DEL │
# │ K          ┆ ---     ┆ BER        ┆ R          ┆   ┆ Y_FOR_ARRI ┆ AIRPLANE  ┆ ---    ┆ AY        │
# │ ---        ┆ str     ┆ ---        ┆ ---        ┆   ┆ VAL        ┆ ---       ┆ str    ┆ ---       │
# │ str        ┆         ┆ i64        ┆ str        ┆   ┆ ---        ┆ f64       ┆        ┆ i64       │
# │            ┆         ┆            ┆            ┆   ┆ str        ┆           ┆        ┆           │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪════════════╪═══════════╪════════╪═══════════╡
# │ Thursday   ┆ DL      ┆ 806        ┆ N3730B     ┆ … ┆ Morning    ┆ 414.52173 ┆ Winter ┆ 3         │
# │            ┆         ┆            ┆            ┆   ┆            ┆ 9         ┆        ┆           │
# │ Thursday   ┆ DL      ┆ 1173       ┆ N826DN     ┆ … ┆ Morning    ┆ 516.35468 ┆ Winter ┆ -12       │
# │ Thursday   ┆ DL      ┆ 2336       ┆ N958DN     ┆ … ┆ Night      ┆ 482.81879 ┆ Winter ┆ -36       │
# │            ┆         ┆            ┆            ┆   ┆            ┆ 2         ┆        ┆           │
# │ Thursday   ┆ DL      ┆ 1434       ┆ N547US     ┆ … ┆ Morning    ┆ 438.57142 ┆ Winter ┆ -4        │
# │            ┆         ┆            ┆            ┆   ┆            ┆ 9         ┆        ┆           │
# │ Thursday   ┆ DL      ┆ 2324       ┆ N3751B     ┆ … ┆ Night      ┆ 479.39698 ┆ Winter ┆ -28       │
# │            ┆         ┆            ┆            ┆   ┆            ┆ 5         ┆        ┆           │
# └────────────┴─────────┴────────────┴────────────┴───┴────────────┴───────────┴────────┴───────────┘

# %% [markdown]
# ## Bivariate Analysis

# %%
colors = ['firebrick', 'gold', 'lightcoral', 'aquamarine', 'c', 'yellowgreen', 'grey',
          'seagreen', 'tomato', 'violet', 'wheat', 'chartreuse', 'lightskyblue', 'royalblue']

# Create the strip plot
ax3 = sns.stripplot(y="AIRLINE", x="DEPARTURE_DELAY", size=4, palette=colors,
                    data=flight_df_pd, linewidth=0.5, jitter=True)

# Set the fontsize for x and y tick labels
plt.setp(ax3.get_xticklabels(), fontsize=14)
plt.setp(ax3.get_yticklabels(), fontsize=14)

# Format x-tick labels to 'h m' format after drawing
plt.draw()
ax3.set_xticklabels(['{:2.0f}h{:02.0f}m'.format(*divmod(x, 60)) if x >= 0 else '-{:2.0f}h{:02.0f}m'.format(*divmod(-x, 60)) for x in ax3.get_xticks()])

# Set label for x-axis
plt.xlabel('Departure delay', fontsize=18, bbox={'facecolor':'midnightblue', 'pad':5},
           color='w', labelpad=20)

# Hide y-axis label
ax3.yaxis.label.set_visible(False)

# Adjust layout
plt.tight_layout(w_pad=3)

# Display the plot
plt.show()
# Out:
# C:\Users\ayomi\AppData\Local\Temp\ipykernel_25060\4173532365.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(['{:2.0f}h{:02.0f}m'.format(*divmod(x, 60)) if x >= 0 else '-{:2.0f}h{:02.0f}m'.format(*divmod(-x, 60)) for x in ax3.get_xticks()])

# %%
colors = ['firebrick', 'gold', 'lightcoral', 'aquamarine', 'c', 'yellowgreen', 'grey',
          'seagreen', 'tomato', 'violet', 'wheat', 'chartreuse', 'lightskyblue', 'royalblue']

# Create the strip plot
ax3 = sns.stripplot(y="AIRLINE", x="ARRIVAL_DELAY", size=4, palette=colors,
                    data=flight_df_pd, linewidth=0.5, jitter=True)

# Set the fontsize for x and y tick labels
plt.setp(ax3.get_xticklabels(), fontsize=14)
plt.setp(ax3.get_yticklabels(), fontsize=14)

# Format x-tick labels to 'h m' format after drawing
plt.draw()
ax3.set_xticklabels(['{:2.0f}h{:02.0f}m'.format(*divmod(x, 60)) if x >= 0 else '-{:2.0f}h{:02.0f}m'.format(*divmod(-x, 60)) for x in ax3.get_xticks()])

# Set label for x-axis
plt.xlabel('Arrival delay', fontsize=18, bbox={'facecolor':'midnightblue', 'pad':5},
           color='w', labelpad=20)

# Hide y-axis label
ax3.yaxis.label.set_visible(False)

# Adjust layout
plt.tight_layout(w_pad=3)

# Display the plot
plt.show()
# Out:
# C:\Users\ayomi\AppData\Local\Temp\ipykernel_25060\2373022335.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(['{:2.0f}h{:02.0f}m'.format(*divmod(x, 60)) if x >= 0 else '-{:2.0f}h{:02.0f}m'.format(*divmod(-x, 60)) for x in ax3.get_xticks()])

# %%
import pandas as pd

crosstab = pd.crosstab(flight_df_pd['DAY_OF_WEEK'], flight_df_pd['SEASON'])
print(crosstab)

# Stacked Bar Plot
crosstab.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Day of Week vs Season')
plt.xlabel('Day of Week')
plt.ylabel('Count')
plt.show()
# Out:
# SEASON       Autumn  Spring  Summer  Winter
# DAY_OF_WEEK
# Friday       210783  220331  222890  208205
# Monday       212582  218097  241437  193427
# Saturday     166861  177446  186988  169250
# Sunday       202375  220166  215234  179989
# Thursday     208491  220038  225227  218765
# Tuesday      207159  213621  221132  202688
# Wednesday    210832  216757  222243  206065

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='DEPARTURE_DELAY', y='ARRIVAL_DELAY', data=flight_df_pd)
plt.title('Departure Delay vs Arrival Delay')
plt.xlabel('Departure Delay (minutes)')
plt.ylabel('Arrival Delay (minutes)')
plt.show()

# %%
cancelled_flights = df.filter(pl.col('CANCELLED') == 1)

cancellation_counts = cancelled_flights.groupby(['AIRLINE', 'CANCELLATION_REASON']).agg(
    pl.count('FLIGHT_NUMBER').alias('COUNT')
)


cancellation_counts_pd = cancellation_counts.to_pandas()
plt.figure(figsize=(12, 8))
sns.barplot(x='AIRLINE', y='COUNT', hue='CANCELLATION_REASON', data=cancellation_counts_pd)
plt.title('Cancellation Reasons by Airline')
plt.xlabel('Airline')
plt.ylabel('Number of Cancellations')
plt.show()
# Out:
# C:\Users\ayomi\AppData\Local\Temp\ipykernel_25060\81714747.py:3: DeprecationWarning: `groupby` is deprecated. It has been renamed to `group_by`.
#   cancellation_counts = cancelled_flights.groupby(['AIRLINE', 'CANCELLATION_REASON']).agg(

# %% [markdown]
# ## DATA AGGREGATION

# %% [markdown]
# LONGEST AND SHOUTEST DISTANCE AND THE ROUTE

# %%
import polars as pl

longest_distance = flight_df.select(['DISTANCE', 'ROUTE']).sort('DISTANCE').head(1)

# Finding the shortest distance and its route
shortest_distance = flight_df.select(['DISTANCE', 'ROUTE']).sort('DISTANCE').tail(1)

# Print results
print("Longest Distance and Route:")
print(longest_distance)

print("\nShortest Distance and Route:")
print(shortest_distance)
# Out:
# Longest Distance and Route:
# shape: (1, 2)
# ┌──────────┬─────────┐
# │ DISTANCE ┆ ROUTE   │
# │ ---      ┆ ---     │
# │ i64      ┆ str     │
# ╞══════════╪═════════╡
# │ 21       ┆ EWR-JFK │
# └──────────┴─────────┘
#
# Shortest Distance and Route:
# shape: (1, 2)
# ┌──────────┬─────────┐
# │ DISTANCE ┆ ROUTE   │
# │ ---      ┆ ---     │
# │ i64      ┆ str     │
# ╞══════════╪═════════╡
# │ 4983     ┆ HNL-JFK │
# └──────────┴─────────┘

# %% [markdown]
# AVERAGE TAXI DURATION BY AIRLINE

# %%
flight_df = flight_df.with_columns((pl.col('TAXI_OUT') + pl.col('TAXI_IN')).alias('TOTAL_TAXI_DURATION'))

# Calculate the average taxi duration by airline
average_taxi_by_airline = flight_df.group_by('AIRLINE').agg([
    pl.col('TOTAL_TAXI_DURATION').mean().alias('AVERAGE_TAXI_DURATION')
])

average_taxi_by_airline.head(15)
# Out:
# shape: (14, 2)
# ┌─────────┬───────────────────────┐
# │ AIRLINE ┆ AVERAGE_TAXI_DURATION │
# │ ---     ┆ ---                   │
# │ str     ┆ f64                   │
# ╞═════════╪═══════════════════════╡
# │ B6      ┆ 23.99386              │
# │ MQ      ┆ 25.628789             │
# │ NK      ┆ 24.158753             │
# │ HA      ┆ 17.794501             │
# │ …       ┆ …                     │
# │ WN      ┆ 18.110806             │
# │ EV      ┆ 24.369651             │
# │ AA      ┆ 26.643592             │
# │ F9      ┆ 24.820694             │
# └─────────┴───────────────────────┘

# %% [markdown]
# PERCENTAGE OF FLGIHT DELAY FOR EACH AIRLINE

# %%
df_delay = flight_df.with_columns(
    (pl.col('DEPARTURE_DELAY') > 0).cast(pl.UInt8).alias('IS_DELAYED')
)

percentage_delayed_by_airline = df_delay.group_by('AIRLINE').agg([
    (pl.col('IS_DELAYED').mean() * 100).alias('PERCENTAGE_DELAYED')
])

print(percentage_delayed_by_airline)
# Out:
# shape: (14, 2)
# ┌─────────┬────────────────────┐
# │ AIRLINE ┆ PERCENTAGE_DELAYED │
# │ ---     ┆ ---                │
# │ str     ┆ f64                │
# ╞═════════╪════════════════════╡
# │ F9      ┆ 38.645476          │
# │ HA      ┆ 26.466454          │
# │ DL      ┆ 32.385972          │
# │ VX      ┆ 38.085852          │
# │ …       ┆ …                  │
# │ EV      ┆ 30.486063          │
# │ US      ┆ 32.113435          │
# │ OO      ┆ 29.628069          │
# │ MQ      ┆ 33.439893          │
# └─────────┴────────────────────┘

# %% [markdown]
# AVERAGE DISTANCE BY DAY OF THE WEEK

# %%
average_distance_by_day = flight_df.groupby('DAY_OF_WEEK').agg([
    pl.col('DISTANCE').mean().alias('AVERAGE_DISTANCE')
])

print(average_distance_by_day)
# Out:
# shape: (7, 2)
# ┌─────────────┬──────────────────┐
# │ DAY_OF_WEEK ┆ AVERAGE_DISTANCE │
# │ ---         ┆ ---              │
# │ str         ┆ f64              │
# ╞═════════════╪══════════════════╡
# │ Friday      ┆ 817.928374       │
# │ Tuesday     ┆ 809.096095       │
# │ Thursday    ┆ 818.616981       │
# │ Wednesday   ┆ 811.784365       │
# │ Saturday    ┆ 857.545201       │
# │ Sunday      ┆ 831.991691       │
# │ Monday      ┆ 816.347052       │
# └─────────────┴──────────────────┘
# C:\Users\ayomi\AppData\Local\Temp\ipykernel_25060\2603035403.py:1: DeprecationWarning: `groupby` is deprecated. It has been renamed to `group_by`.
#   average_distance_by_day = flight_df.groupby('DAY_OF_WEEK').agg([

# %% [markdown]
# TOTAL FLIGHT BY DAY OF THE WEEK

# %%
total_flights_by_day = flight_df.groupby('DAY_OF_WEEK').agg([
    pl.count('FLIGHT_NUMBER').alias('TOTAL_FLIGHTS')
])

print(total_flights_by_day.sort('TOTAL_FLIGHTS', descending=True))
# Out:
# C:\Users\ayomi\AppData\Local\Temp\ipykernel_25060\1138684646.py:1: DeprecationWarning: `groupby` is deprecated. It has been renamed to `group_by`.
#   total_flights_by_day = flight_df.groupby('DAY_OF_WEEK').agg([
# shape: (7, 2)
# ┌─────────────┬───────────────┐
# │ DAY_OF_WEEK ┆ TOTAL_FLIGHTS │
# │ ---         ┆ ---           │
# │ str         ┆ u32           │
# ╞═════════════╪═══════════════╡
# │ Thursday    ┆ 872521        │
# │ Monday      ┆ 865543        │
# │ Friday      ┆ 862209        │
# │ Wednesday   ┆ 855897        │
# │ Tuesday     ┆ 844600        │
# │ Sunday      ┆ 817764        │
# │ Saturday    ┆ 700545        │
# └─────────────┴───────────────┘

# %% [markdown]
# AVERAGE SPEED BASED ON AIRLINE

# %%
average_speed_by_airline = flight_df.group_by('AIRLINE').agg([
    pl.col('SPEED_OF_AIRPLANE').mean().alias('AVERAGE_SPEED')
])

average_speed_by_airline.head(15).sort("AVERAGE_SPEED")
# Out:
# shape: (14, 2)
# ┌─────────┬───────────────┐
# │ AIRLINE ┆ AVERAGE_SPEED │
# │ ---     ┆ ---           │
# │ str     ┆ f64           │
# ╞═════════╪═══════════════╡
# │ HA      ┆ 243.792244    │
# │ MQ      ┆ 258.52292     │
# │ EV      ┆ 269.487384    │
# │ OO      ┆ 271.143919    │
# │ …       ┆ …             │
# │ F9      ┆ 367.108435    │
# │ VX      ┆ 373.845026    │
# │ AS      ┆ 374.173617    │
# │ UA      ┆ 377.010508    │
# └─────────┴───────────────┘
